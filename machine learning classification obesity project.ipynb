# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
obesity = pd.read_csv('ObesityDataSet.csv')

# %%
obesity
# Out:
#             Age  Gender    Height      Weight        CALC FAVC  FCVC  NCP  \
# 0     21.000000  Female  1.620000   64.000000          no   no   2.0  3.0
# 1     21.000000  Female  1.520000   56.000000   Sometimes   no   3.0  3.0
# 2     23.000000    Male  1.800000   77.000000  Frequently   no   2.0  3.0
# 3     27.000000    Male  1.800000   87.000000  Frequently   no   3.0  3.0
# 4     22.000000    Male  1.780000   89.800000   Sometimes   no   2.0  1.0
# ...         ...     ...       ...         ...         ...  ...   ...  ...
# 2106  20.976842  Female  1.710730  131.408528   Sometimes  yes   3.0  3.0
# 2107  21.982942  Female  1.748584  133.742943   Sometimes  yes   3.0  3.0
# 2108  22.524036  Female  1.752206  133.689352   Sometimes  yes   3.0  3.0
# 2109  24.361936  Female  1.739450  133.346641   Sometimes  yes   3.0  3.0
# 2110  23.664709  Female  1.738836  133.472641   Sometimes  yes   3.0  3.0
#
#       SCC SMOKE      CH2O family_history_with_overweight       FAF       TUE  \
# ...

# %%
obesity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Age                             2111 non-null   float64
#  1   Gender                          2111 non-null   object
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   CALC                            2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   SCC                             2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  family_history_with_overweight  2111 non-null   object
# ...

# %%
obesity.isna().sum()
# Out:
# Age                               0
# Gender                            0
# Height                            0
# Weight                            0
# CALC                              0
# FAVC                              0
# FCVC                              0
# NCP                               0
# SCC                               0
# SMOKE                             0
# CH2O                              0
# family_history_with_overweight    0
# FAF                               0
# TUE                               0
# CAEC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
obesity.nunique()
# Out:
# Age                               1402
# Gender                               2
# Height                            1574
# Weight                            1525
# CALC                                 4
# FAVC                                 2
# FCVC                               810
# NCP                                635
# SCC                                  2
# SMOKE                                2
# CH2O                              1268
# family_history_with_overweight       2
# FAF                               1190
# TUE                               1129
# CAEC                                 4
# MTRANS                               5
# NObeyesdad                           7
# dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.countplot(x = 'NObeyesdad' , data = obesity)
# Out:
# <Axes: xlabel='NObeyesdad', ylabel='count'>

# %%
from sklearn.preprocessing import LabelEncoder

# %%
en = LabelEncoder()

# %%
obesity['Gender'] = en.fit_transform(obesity['Gender'])

# %%
obesity['FAVC'] = en.fit_transform(obesity['FAVC'])

# %%
obesity['CALC'] = en.fit_transform(obesity['CALC'])

# %%
obesity['SCC'] = en.fit_transform(obesity['SCC'])

# %%
obesity['SMOKE'] = en.fit_transform(obesity['SMOKE'])

# %%
obesity['family_history_with_overweight'] = en.fit_transform(obesity['family_history_with_overweight'])

# %%
obesity['CAEC'] = en.fit_transform(obesity['CAEC'])

# %%
obesity['MTRANS'] = en.fit_transform(obesity['MTRANS'])

# %%
obesity['NObeyesdad'] = en.fit_transform(obesity['NObeyesdad'])

# %%
obesity
# Out:
#             Age  Gender    Height      Weight  CALC  FAVC  FCVC  NCP  SCC  \
# 0     21.000000       0  1.620000   64.000000     3     0   2.0  3.0    0
# 1     21.000000       0  1.520000   56.000000     2     0   3.0  3.0    1
# 2     23.000000       1  1.800000   77.000000     1     0   2.0  3.0    0
# 3     27.000000       1  1.800000   87.000000     1     0   3.0  3.0    0
# 4     22.000000       1  1.780000   89.800000     2     0   2.0  1.0    0
# ...         ...     ...       ...         ...   ...   ...   ...  ...  ...
# 2106  20.976842       0  1.710730  131.408528     2     1   3.0  3.0    0
# 2107  21.982942       0  1.748584  133.742943     2     1   3.0  3.0    0
# 2108  22.524036       0  1.752206  133.689352     2     1   3.0  3.0    0
# 2109  24.361936       0  1.739450  133.346641     2     1   3.0  3.0    0
# 2110  23.664709       0  1.738836  133.472641     2     1   3.0  3.0    0
#
#       SMOKE      CH2O  family_history_with_overweight       FAF       TUE  \
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(obesity.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.scatterplot(x='Weight', y = 'FAF',hue= 'NObeyesdad',data=obesity)
# Out:
# <Axes: xlabel='Weight', ylabel='FAF'>

# %%
sns.scatterplot(x='Height', y = 'Weight',hue= 'NObeyesdad',data=obesity)
# Out:
# <Axes: xlabel='Height', ylabel='Weight'>

# %%
sns.pairplot(obesity, hue='NObeyesdad')

# %%
X = obesity.iloc[:,:-1].values

# %%
X
# Out:
# array([[21.      ,  0.      ,  1.62    , ...,  1.      ,  2.      ,
#          3.      ],
#        [21.      ,  0.      ,  1.52    , ...,  0.      ,  2.      ,
#          3.      ],
#        [23.      ,  1.      ,  1.8     , ...,  1.      ,  2.      ,
#          3.      ],
#        ...,
#        [22.524036,  0.      ,  1.752206, ...,  0.646288,  2.      ,
#          3.      ],
#        [24.361936,  0.      ,  1.73945 , ...,  0.586035,  2.      ,
#          3.      ],
#        [23.664709,  0.      ,  1.738836, ...,  0.714137,  2.      ,
#          3.      ]])

# %%
y = obesity.iloc[:,-1].values

# %%
y
# Out:
# array([1, 1, 1, ..., 4, 4, 4])

# %% [markdown]
# ## Data Splitting & Preprocessing

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , y_train , y_test = train_test_split(X,y,test_size=.20,random_state=42)

# %%
X_train.shape
# Out:
# (1688, 16)

# %%
X_test.shape
# Out:
# (423, 16)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
X_train = sc.fit_transform(X_train)

# %%
X_test = sc.transform(X_test)

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
classifier = KNeighborsClassifier(n_neighbors=4,metric='euclidean')

# %%
classifier.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=4)

# %%
y_pred = classifier.predict(X_test)
# Out:
# D:\python\pythonanaconda\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "D:\python\pythonanaconda\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#         "wmic CPU Get NumberOfCores /Format:csv".split(),
#         capture_output=True,
#         text=True,
#     )
#   File "D:\python\pythonanaconda\Lib\subprocess.py", line 554, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\python\pythonanaconda\Lib\subprocess.py", line 1039, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
# ...

# %%
print('y_test',y_test)
print('===============================')
print('y_pred',y_pred)
# Out:
# y_test [0 4 0 0 1 0 3 5 2 0 2 4 3 3 4 6 4 3 2 6 2 5 4 2 1 6 6 4 4 0 4 5 6 1 0 4 2
#  1 1 1 1 3 1 1 5 0 3 1 2 3 1 1 1 5 0 6 3 3 5 3 1 4 6 0 3 2 1 4 0 1 6 6 0 0
#  5 3 3 1 4 3 1 2 3 3 2 2 1 6 1 6 5 3 0 5 2 0 5 2 1 3 2 2 4 2 6 2 1 4 4 3 2
#  1 2 1 0 2 2 3 6 1 4 3 2 6 1 3 2 2 4 3 4 3 1 2 6 4 0 4 5 2 5 6 0 0 1 3 2 4
#  0 2 0 0 1 3 2 5 6 5 0 0 1 1 2 0 3 0 2 1 5 6 1 6 3 4 2 6 2 6 2 5 0 3 0 5 3
#  2 5 4 3 3 0 4 0 1 4 5 3 2 4 0 3 3 4 4 1 4 5 5 2 4 5 2 0 2 3 0 5 3 3 3 4 6
#  3 5 3 6 0 4 5 5 5 4 1 5 1 2 2 2 2 0 6 6 5 2 2 2 1 2 2 0 5 2 0 1 1 6 2 3 2
#  2 4 4 5 2 2 4 4 1 1 4 2 4 6 2 3 2 3 4 3 1 0 5 6 4 4 5 2 6 0 3 2 5 1 2 0 5
#  3 3 6 6 1 5 0 0 5 1 6 5 6 4 5 3 1 4 5 6 2 4 6 1 0 1 4 0 1 4 2 2 4 0 1 1 3
#  4 2 5 2 0 0 0 2 4 6 2 4 3 5 2 5 6 6 4 6 1 0 6 6 6 5 6 6 3 2 2 3 4 2 6 5 4
#  0 2 1 3 2 5 0 1 2 2 6 6 1 0 4 5 4 4 1 2 3 5 4 6 3 5 0 4 5 4 1 0 1 5 2 1 0
#  4 1 4 6 5 5 5 4 0 5 2 5 3 1 3 6]
# ...
# y_pred [0 4 1 0 6 0 3 2 2 0 2 4 3 3 4 0 4 3 2 6 2 5 4 2 1 6 6 4 4 0 4 5 6 1 0 4 2
# ...

# %%
from sklearn.metrics import confusion_matrix , accuracy_score , classification_report

# %%
cm = confusion_matrix(y_test , y_pred)
cm
# Out:
# array([[53,  2,  0,  0,  0,  1,  0],
#        [15, 29,  5,  0,  0,  4,  9],
#        [ 0,  0, 71,  2,  0,  2,  3],
#        [ 0,  0,  2, 56,  0,  0,  0],
#        [ 0,  0,  0,  0, 63,  0,  0],
#        [ 2, 10,  3,  0,  0, 38,  3],
#        [ 1,  2,  4,  3,  1,  2, 37]])

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.95      0.83        56
#            1       0.67      0.47      0.55        62
#            2       0.84      0.91      0.87        78
#            3       0.92      0.97      0.94        58
#            4       0.98      1.00      0.99        63
#            5       0.81      0.68      0.74        56
#            6       0.71      0.74      0.73        50
#
#     accuracy                           0.82       423
#    macro avg       0.81      0.82      0.81       423
# weighted avg       0.82      0.82      0.81       423

# %%
test_error_rate = []
for i in range (3,30):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    y_pred_elbow = knn.predict(X_test)
    test_error = 1 - accuracy_score(y_test,y_pred_elbow)
    test_error_rate.append(test_error)

# %%
test_error_rate
# Out:
# [0.182033096926714,
#  0.17966903073286056,
#  0.17966903073286056,
#  0.18912529550827428,
#  0.20094562647754133,
#  0.20803782505910162,
#  0.21513002364066192,
#  0.21276595744680848,
#  0.22695035460992907,
#  0.2222222222222222,
#  0.24113475177304966,
#  0.24113475177304966,
#  0.2529550827423168,
#  0.26241134751773054,
#  0.2576832151300237,
#  0.25531914893617025,
#  0.25531914893617025,
#  0.2576832151300237,
#  0.27186761229314416,
#  0.2671394799054374,
#  0.2813238770685579,
#  0.27895981087470445,
#  0.2884160756501182,
#  0.28605200945626474,
#  0.30023640661938533,
#  0.30023640661938533,
#  0.3049645390070922]

# %%
plt.plot(range(3,30),test_error_rate,label='error_testing')
plt.legend()

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVC

# %%
svc_model = SVC()

# %%
svc_model.fit(X_train,y_train)
# Out:
# SVC()

# %%
y_predict_svc = svc_model.predict(X_test)

# %%
print(confusion_matrix(y_test,y_predict_svc))
# Out:
# [[52  4  0  0  0  0  0]
#  [ 3 52  1  0  0  4  2]
#  [ 0  0 70  4  0  2  2]
#  [ 0  0  1 57  0  0  0]
#  [ 0  0  0  0 63  0  0]
#  [ 1 12  0  0  0 41  2]
#  [ 0  2  2  0  0  5 41]]

# %%
print(classification_report(y_test,y_predict_svc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93        56
#            1       0.74      0.84      0.79        62
#            2       0.95      0.90      0.92        78
#            3       0.93      0.98      0.96        58
#            4       1.00      1.00      1.00        63
#            5       0.79      0.73      0.76        56
#            6       0.87      0.82      0.85        50
#
#     accuracy                           0.89       423
#    macro avg       0.89      0.89      0.89       423
# weighted avg       0.89      0.89      0.89       423

# %%
print('y_test',y_test)
print('===============================')
print('y_predict_svc',y_predict_svc)
# Out:
# y_test [0 4 0 0 1 0 3 5 2 0 2 4 3 3 4 6 4 3 2 6 2 5 4 2 1 6 6 4 4 0 4 5 6 1 0 4 2
#  1 1 1 1 3 1 1 5 0 3 1 2 3 1 1 1 5 0 6 3 3 5 3 1 4 6 0 3 2 1 4 0 1 6 6 0 0
#  5 3 3 1 4 3 1 2 3 3 2 2 1 6 1 6 5 3 0 5 2 0 5 2 1 3 2 2 4 2 6 2 1 4 4 3 2
#  1 2 1 0 2 2 3 6 1 4 3 2 6 1 3 2 2 4 3 4 3 1 2 6 4 0 4 5 2 5 6 0 0 1 3 2 4
#  0 2 0 0 1 3 2 5 6 5 0 0 1 1 2 0 3 0 2 1 5 6 1 6 3 4 2 6 2 6 2 5 0 3 0 5 3
#  2 5 4 3 3 0 4 0 1 4 5 3 2 4 0 3 3 4 4 1 4 5 5 2 4 5 2 0 2 3 0 5 3 3 3 4 6
#  3 5 3 6 0 4 5 5 5 4 1 5 1 2 2 2 2 0 6 6 5 2 2 2 1 2 2 0 5 2 0 1 1 6 2 3 2
#  2 4 4 5 2 2 4 4 1 1 4 2 4 6 2 3 2 3 4 3 1 0 5 6 4 4 5 2 6 0 3 2 5 1 2 0 5
#  3 3 6 6 1 5 0 0 5 1 6 5 6 4 5 3 1 4 5 6 2 4 6 1 0 1 4 0 1 4 2 2 4 0 1 1 3
#  4 2 5 2 0 0 0 2 4 6 2 4 3 5 2 5 6 6 4 6 1 0 6 6 6 5 6 6 3 2 2 3 4 2 6 5 4
#  0 2 1 3 2 5 0 1 2 2 6 6 1 0 4 5 4 4 1 2 3 5 4 6 3 5 0 4 5 4 1 0 1 5 2 1 0
#  4 1 4 6 5 5 5 4 0 5 2 5 3 1 3 6]
# ...
# y_predict_svc [0 4 1 0 6 0 3 5 2 0 2 4 3 3 4 1 4 3 3 6 2 5 4 2 1 6 6 4 4 0 4 5 5 1 0 4 2
# ...

# %% [markdown]
# ## LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(X_train , y_train)
# Out:
# LogisticRegression()

# %%
y_pred_lr = lr.predict(X_test)

# %%
print('y_test',y_test)
print('===============================')
print('y_predict_lr',y_pred_lr)
# Out:
# y_test [0 4 0 0 1 0 3 5 2 0 2 4 3 3 4 6 4 3 2 6 2 5 4 2 1 6 6 4 4 0 4 5 6 1 0 4 2
#  1 1 1 1 3 1 1 5 0 3 1 2 3 1 1 1 5 0 6 3 3 5 3 1 4 6 0 3 2 1 4 0 1 6 6 0 0
#  5 3 3 1 4 3 1 2 3 3 2 2 1 6 1 6 5 3 0 5 2 0 5 2 1 3 2 2 4 2 6 2 1 4 4 3 2
#  1 2 1 0 2 2 3 6 1 4 3 2 6 1 3 2 2 4 3 4 3 1 2 6 4 0 4 5 2 5 6 0 0 1 3 2 4
#  0 2 0 0 1 3 2 5 6 5 0 0 1 1 2 0 3 0 2 1 5 6 1 6 3 4 2 6 2 6 2 5 0 3 0 5 3
#  2 5 4 3 3 0 4 0 1 4 5 3 2 4 0 3 3 4 4 1 4 5 5 2 4 5 2 0 2 3 0 5 3 3 3 4 6
#  3 5 3 6 0 4 5 5 5 4 1 5 1 2 2 2 2 0 6 6 5 2 2 2 1 2 2 0 5 2 0 1 1 6 2 3 2
#  2 4 4 5 2 2 4 4 1 1 4 2 4 6 2 3 2 3 4 3 1 0 5 6 4 4 5 2 6 0 3 2 5 1 2 0 5
#  3 3 6 6 1 5 0 0 5 1 6 5 6 4 5 3 1 4 5 6 2 4 6 1 0 1 4 0 1 4 2 2 4 0 1 1 3
#  4 2 5 2 0 0 0 2 4 6 2 4 3 5 2 5 6 6 4 6 1 0 6 6 6 5 6 6 3 2 2 3 4 2 6 5 4
#  0 2 1 3 2 5 0 1 2 2 6 6 1 0 4 5 4 4 1 2 3 5 4 6 3 5 0 4 5 4 1 0 1 5 2 1 0
#  4 1 4 6 5 5 5 4 0 5 2 5 3 1 3 6]
# ...
# y_predict_lr [0 4 0 0 6 0 3 5 2 0 2 4 3 3 4 2 4 3 3 6 2 5 4 2 0 6 6 4 4 0 4 6 5 0 0 4 2
# ...

# %%
print(confusion_matrix(y_test,y_pred_lr))
# Out:
# [[56  0  0  0  0  0  0]
#  [11 39  0  0  0  8  4]
#  [ 0  0 70  7  0  0  1]
#  [ 0  0  2 56  0  0  0]
#  [ 0  0  0  0 63  0  0]
#  [ 0  4  0  0  0 44  8]
#  [ 0  0  3  0  0  5 42]]

# %%
print(classification_report(y_test,y_pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91        56
#            1       0.91      0.63      0.74        62
#            2       0.93      0.90      0.92        78
#            3       0.89      0.97      0.93        58
#            4       1.00      1.00      1.00        63
#            5       0.77      0.79      0.78        56
#            6       0.76      0.84      0.80        50
#
#     accuracy                           0.87       423
#    macro avg       0.87      0.87      0.87       423
# weighted avg       0.88      0.87      0.87       423

# %% [markdown]
# ## DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier ,plot_tree

# %%
dtc = DecisionTreeClassifier(random_state=42)

# %%
dtc.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred_dtc = dtc.predict(X_test)

# %%
print('y_test',y_test)
print('===============================')
print('y_predict_dtc',y_pred_dtc)
# Out:
# y_test [0 4 0 0 1 0 3 5 2 0 2 4 3 3 4 6 4 3 2 6 2 5 4 2 1 6 6 4 4 0 4 5 6 1 0 4 2
#  1 1 1 1 3 1 1 5 0 3 1 2 3 1 1 1 5 0 6 3 3 5 3 1 4 6 0 3 2 1 4 0 1 6 6 0 0
#  5 3 3 1 4 3 1 2 3 3 2 2 1 6 1 6 5 3 0 5 2 0 5 2 1 3 2 2 4 2 6 2 1 4 4 3 2
#  1 2 1 0 2 2 3 6 1 4 3 2 6 1 3 2 2 4 3 4 3 1 2 6 4 0 4 5 2 5 6 0 0 1 3 2 4
#  0 2 0 0 1 3 2 5 6 5 0 0 1 1 2 0 3 0 2 1 5 6 1 6 3 4 2 6 2 6 2 5 0 3 0 5 3
#  2 5 4 3 3 0 4 0 1 4 5 3 2 4 0 3 3 4 4 1 4 5 5 2 4 5 2 0 2 3 0 5 3 3 3 4 6
#  3 5 3 6 0 4 5 5 5 4 1 5 1 2 2 2 2 0 6 6 5 2 2 2 1 2 2 0 5 2 0 1 1 6 2 3 2
#  2 4 4 5 2 2 4 4 1 1 4 2 4 6 2 3 2 3 4 3 1 0 5 6 4 4 5 2 6 0 3 2 5 1 2 0 5
#  3 3 6 6 1 5 0 0 5 1 6 5 6 4 5 3 1 4 5 6 2 4 6 1 0 1 4 0 1 4 2 2 4 0 1 1 3
#  4 2 5 2 0 0 0 2 4 6 2 4 3 5 2 5 6 6 4 6 1 0 6 6 6 5 6 6 3 2 2 3 4 2 6 5 4
#  0 2 1 3 2 5 0 1 2 2 6 6 1 0 4 5 4 4 1 2 3 5 4 6 3 5 0 4 5 4 1 0 1 5 2 1 0
#  4 1 4 6 5 5 5 4 0 5 2 5 3 1 3 6]
# ...
# y_predict_dtc [0 4 0 0 1 0 3 5 2 0 2 4 2 3 4 6 4 3 2 6 2 5 4 2 1 6 6 4 4 0 4 5 6 1 0 4 2
# ...

# %%
print(confusion_matrix(y_test,y_pred_dtc))
# Out:
# [[55  1  0  0  0  0  0]
#  [ 5 53  0  0  0  4  0]
#  [ 0  0 74  2  0  1  1]
#  [ 0  0  3 55  0  0  0]
#  [ 0  0  0  0 63  0  0]
#  [ 0  4  0  0  0 52  0]
#  [ 0  0  0  0  0  2 48]]

# %%
print(classification_report(y_test,y_pred_dtc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95        56
#            1       0.91      0.85      0.88        62
#            2       0.96      0.95      0.95        78
#            3       0.96      0.95      0.96        58
#            4       1.00      1.00      1.00        63
#            5       0.88      0.93      0.90        56
#            6       0.98      0.96      0.97        50
#
#     accuracy                           0.95       423
#    macro avg       0.95      0.95      0.95       423
# weighted avg       0.95      0.95      0.95       423

# %%
plt.figure(figsize=(12,12))
plot_tree(dtc,filled=True,rounded=True,max_depth=5)
plt.show()
